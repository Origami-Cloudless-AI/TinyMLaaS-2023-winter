# %% [markdown]
# # TinyMLaaS
# Experiment here

# %%
import pandas as pd

# %%
df = pd.read_csv("TinyMLaaS.csv")
df
# Out:
#                                           Device name    "IP address"  \
# 0                                       Simulator x86   "192.168.1.1"
# 1                           Arduino Nano 33 BLE Sense     192.168.1.2
# 2                                       SparkFun Edge     192.168.1.3
# 3                             STM32F746 Discovery kit     192.168.1.4
# 4                                  Adafruit EdgeBadge     192.168.1.5
# 5   Adafruit TensorFlow Lite for Microcontrollers Kit     192.168.1.6
# 6               Adafruit Circuit Playground Bluefruit     192.168.1.7
# 7                             Espressif ESP32-DevKitC     192.168.1.8
# 8                                   Espressif ESP-EYE     192.168.1.9
# 9                              Wio Terminal: ATSAMD51    192.168.1.11
# 10  Himax WE-I Plus EVB Endpoint AI Development Board    192.168.1.11
# 11  Synopsys DesignWare ARC EM Software Developmen...    192.168.1.12
# ...
